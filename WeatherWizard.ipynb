# %%
import pandas as pd
import numpy as np

# %%
print('Wennie test')
# Out:
# Wennie test

# %%
def load_csv(file_name):
  # Input: csv_file_name
  # Output: pandas data frame
    df = pd.read_csv(file_name, sep = ',')
    return df

# %%
humidity= load_csv('/content/humidity.csv')
pressure= load_csv('/content/pressure.csv')
temperature= load_csv('/content/temperature.csv')
label= load_csv('/content/weather_description.csv')

# %%
humidity= humidity.drop(humidity.index[0])
humidity.head(3)
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 1  2012-10-01 13:00:00       76.0      81.0           88.0     81.0
# 2  2012-10-01 14:00:00       76.0      80.0           87.0     80.0
# 3  2012-10-01 15:00:00       76.0      80.0           86.0     80.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 1         88.0       82.0       22.0     23.0         50.0  ...          71.0
# 2         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 3         88.0       81.0       21.0     23.0         49.0  ...          70.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# 1      58.0      93.0    68.0       50.0               63.0   22.0   51.0
# 2      57.0      91.0    68.0       51.0               62.0   22.0   51.0
# 3      57.0      87.0    68.0       51.0               62.0   22.0   51.0
#
#    Nahariyya  Jerusalem
# 1       51.0       50.0
# 2       51.0       50.0
# 3       51.0       50.0
#
# [3 rows x 37 columns]

# %%
pressure= pressure.drop(pressure.index[0])
pressure.head(3)
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 1  2012-10-01 13:00:00        NaN    1024.0         1009.0   1027.0
# 2  2012-10-01 14:00:00        NaN    1024.0         1009.0   1027.0
# 3  2012-10-01 15:00:00        NaN    1024.0         1009.0   1028.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 1       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
# 2       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
# 3       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District   Eilat   Haifa  \
# 1    1012.0    1001.0  1014.0      984.0             1012.0  1010.0  1013.0
# 2    1012.0     986.0  1014.0      984.0             1012.0  1010.0  1013.0
# 3    1012.0     945.0  1014.0      984.0             1012.0  1010.0  1013.0
#
#    Nahariyya  Jerusalem
# 1     1013.0      990.0
# 2     1013.0      990.0
# 3     1013.0      990.0
#
# [3 rows x 37 columns]

# %%
temperature= temperature.drop(temperature.index[0])
temperature.head(3)
# Out:
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
#
#    Philadelphia    New York   Montreal      Boston   Beersheba  \
# 1    285.630000  288.220000  285.83000  287.170000  307.590000
# 2    285.663208  288.247676  285.83465  287.186092  307.590000
# 3    285.756824  288.326940  285.84779  287.231672  307.391513
#
#    Tel Aviv District       Eilat  Haifa  Nahariyya  Jerusalem
# 1         305.470000  310.580000  304.4      304.4      303.5
# 2         304.310000  310.495769  304.4      304.4      303.5
# 3         304.281841  310.411538  304.4      304.4      303.5
#
# [3 rows x 37 columns]

# %%
label= label.drop(label.index[0])
label.head(5)
# Out:
#               datetime      Vancouver          Portland San Francisco  \
# 1  2012-10-01 13:00:00           mist  scattered clouds    light rain
# 2  2012-10-01 14:00:00  broken clouds  scattered clouds  sky is clear
# 3  2012-10-01 15:00:00  broken clouds  scattered clouds  sky is clear
# 4  2012-10-01 16:00:00  broken clouds  scattered clouds  sky is clear
# 5  2012-10-01 17:00:00  broken clouds  scattered clouds  sky is clear
#
#         Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# 1  sky is clear          mist  sky is clear  sky is clear  sky is clear
# 2  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 3  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 4  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 5  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
#
#     Albuquerque  ...   Philadelphia    New York         Montreal  \
# 1  sky is clear  ...  broken clouds  few clouds  overcast clouds
# 2  sky is clear  ...  broken clouds  few clouds     sky is clear
# 3  sky is clear  ...  broken clouds  few clouds     sky is clear
# 4  sky is clear  ...  broken clouds  few clouds     sky is clear
# 5  sky is clear  ...  broken clouds  few clouds     sky is clear
#
#          Boston        Beersheba Tel Aviv District          Eilat  \
# 1  sky is clear     sky is clear      sky is clear           haze
# 2    few clouds     sky is clear      sky is clear  broken clouds
# 3    few clouds  overcast clouds      sky is clear  broken clouds
# 4    few clouds  overcast clouds      sky is clear  broken clouds
# 5    few clouds  overcast clouds      sky is clear  broken clouds
#
#              Haifa        Nahariyya        Jerusalem
# 1     sky is clear     sky is clear     sky is clear
# 2  overcast clouds     sky is clear  overcast clouds
# 3  overcast clouds  overcast clouds  overcast clouds
# 4  overcast clouds  overcast clouds  overcast clouds
# 5  overcast clouds  overcast clouds  overcast clouds
#
# [5 rows x 37 columns]

# %%
all_col= ['Vancouver', 'Portland', 'San Francisco','Seattle', 'Los Angeles', 'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Philadelphia', 'New York', 'Montreal', 'Boston', 'Beersheba',	'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya',	'Jerusalem']
temperature[all_col]= temperature[all_col]-273.15
temperature.head(3)
# Out:
#               datetime  Vancouver  Portland  San Francisco   Seattle  \
# 1  2012-10-01 13:00:00  11.480000  8.930000      16.330000  8.650000
# 2  2012-10-01 14:00:00  11.479041  8.933252      16.324993  8.647217
# 3  2012-10-01 15:00:00  11.476998  8.941866      16.310618  8.639833
#
#    Los Angeles  San Diego  Las Vegas    Phoenix  Albuquerque  ...  \
# 1    18.720000  18.380000  20.260000  23.450000    11.970000  ...
# 2    18.718186  18.383501  20.253141  23.458509    12.004558  ...
# 3    18.712844  18.393355  20.242177  23.481487    12.083952  ...
#
#    Philadelphia   New York  Montreal     Boston  Beersheba  Tel Aviv District  \
# 1     12.480000  15.070000  12.68000  14.020000  34.440000          32.320000
# 2     12.513208  15.097676  12.68465  14.036092  34.440000          31.160000
# 3     12.606824  15.176940  12.69779  14.081672  34.241513          31.131841
#
#        Eilat  Haifa  Nahariyya  Jerusalem
# 1  37.430000  31.25      31.25      30.35
# 2  37.345769  31.25      31.25      30.35
# 3  37.261538  31.25      31.25      30.35
#
# [3 rows x 37 columns]

# %%
t1= pd.merge(left= pressure, right= temperature, on= 'datetime', suffixes=("_pressure", "_tempreture"))
t1.head(10)
# Out:
#               datetime  Vancouver_pressure  Portland_pressure  \
# 0  2012-10-01 13:00:00                 NaN             1024.0
# 1  2012-10-01 14:00:00                 NaN             1024.0
# 2  2012-10-01 15:00:00                 NaN             1024.0
# 3  2012-10-01 16:00:00                 NaN             1024.0
# 4  2012-10-01 17:00:00                 NaN             1024.0
# 5  2012-10-01 18:00:00                 NaN             1024.0
# 6  2012-10-01 19:00:00                 NaN             1024.0
# 7  2012-10-01 20:00:00                 NaN             1024.0
# 8  2012-10-01 21:00:00                 NaN             1024.0
# 9  2012-10-01 22:00:00                 NaN             1024.0
#
#    San Francisco_pressure  Seattle_pressure  Los Angeles_pressure  \
# 0                  1009.0            1027.0                1013.0
# 1                  1009.0            1027.0                1013.0
# 2                  1009.0            1028.0                1013.0
# 3                  1009.0            1028.0                1013.0
# 4                  1009.0            1029.0                1013.0
# 5                  1010.0            1030.0                1013.0
# 6                  1010.0            1031.0                1013.0
# 7                  1010.0            1031.0                1013.0
# 8                  1010.0            1032.0                1013.0
# 9                  1011.0            1033.0                1013.0
#
#    San Diego_pressure  Las Vegas_pressure  Phoenix_pressure  \
# 0              1013.0              1018.0            1013.0
# 1              1013.0              1018.0            1013.0
# 2              1013.0              1018.0            1013.0
# 3              1013.0              1018.0            1013.0
# 4              1013.0              1018.0            1013.0
# 5              1013.0              1018.0            1013.0
# 6              1013.0              1018.0            1013.0
# 7              1013.0              1018.0            1013.0
# 8              1013.0              1018.0            1013.0
# 9              1013.0              1018.0            1013.0
#
#    Albuquerque_pressure  ...  Philadelphia_tempreture  New York_tempreture  \
# 0                1024.0  ...                12.480000            15.070000
# 1                1024.0  ...                12.513208            15.097676
# 2                1024.0  ...                12.606824            15.176940
# 3                1024.0  ...                12.700440            15.256203
# 4                1024.0  ...                12.794057            15.335467
# 5                1024.0  ...                12.887673            15.414730
# 6                1024.0  ...                12.981290            15.493994
# 7                1024.0  ...                13.074906            15.573257
# 8                1024.0  ...                13.168522            15.652521
# 9                1024.0  ...                13.262139            15.731784
#
#    Montreal_tempreture  Boston_tempreture  Beersheba_tempreture  \
# 0            12.680000          14.020000             34.440000
# 1            12.684650          14.036092             34.440000
# 2            12.697790          14.081672             34.241513
# 3            12.710929          14.127251             33.995200
# 4            12.724069          14.172831             33.748887
# 5            12.737208          14.218410             33.502574
# 6            12.750348          14.263990             33.256261
# 7            12.763487          14.309569             33.009948
# 8            12.776627          14.355149             32.763635
# 9            12.789767          14.400728             32.517322
#
#    Tel Aviv District_tempreture  Eilat_tempreture  Haifa_tempreture  \
# 0                     32.320000         37.430000             31.25
# 1                     31.160000         37.345769             31.25
# 2                     31.131841         37.261538             31.25
# 3                     31.088015         37.177308             31.25
# 4                     31.044188         37.093077             31.25
# 5                     31.000361         37.008846             31.25
# 6                     30.956534         36.924615             31.25
# 7                     30.912708         36.840385             31.25
# 8                     30.868881         36.756154             31.25
# 9                     30.825054         36.671923             31.25
#
#    Nahariyya_tempreture  Jerusalem_tempreture
# 0                 31.25                 30.35
# 1                 31.25                 30.35
# 2                 31.25                 30.35
# 3                 31.25                 30.35
# 4                 31.25                 30.35
# 5                 31.25                 30.35
# 6                 31.25                 30.35
# 7                 31.25                 30.35
# 8                 31.25                 30.35
# 9                 31.25                 30.35
#
# [10 rows x 73 columns]

# %%
t2= pd.merge(left= t1, right=humidity, on= 'datetime')
t2.head(10)
#_x= pressure, _y= temp, NULL= humidity
# Out:
#               datetime  Vancouver_pressure  Portland_pressure  \
# 0  2012-10-01 13:00:00                 NaN             1024.0
# 1  2012-10-01 14:00:00                 NaN             1024.0
# 2  2012-10-01 15:00:00                 NaN             1024.0
# 3  2012-10-01 16:00:00                 NaN             1024.0
# 4  2012-10-01 17:00:00                 NaN             1024.0
# 5  2012-10-01 18:00:00                 NaN             1024.0
# 6  2012-10-01 19:00:00                 NaN             1024.0
# 7  2012-10-01 20:00:00                 NaN             1024.0
# 8  2012-10-01 21:00:00                 NaN             1024.0
# 9  2012-10-01 22:00:00                 NaN             1024.0
#
#    San Francisco_pressure  Seattle_pressure  Los Angeles_pressure  \
# 0                  1009.0            1027.0                1013.0
# 1                  1009.0            1027.0                1013.0
# 2                  1009.0            1028.0                1013.0
# 3                  1009.0            1028.0                1013.0
# 4                  1009.0            1029.0                1013.0
# 5                  1010.0            1030.0                1013.0
# 6                  1010.0            1031.0                1013.0
# 7                  1010.0            1031.0                1013.0
# 8                  1010.0            1032.0                1013.0
# 9                  1011.0            1033.0                1013.0
#
#    San Diego_pressure  Las Vegas_pressure  Phoenix_pressure  \
# 0              1013.0              1018.0            1013.0
# 1              1013.0              1018.0            1013.0
# 2              1013.0              1018.0            1013.0
# 3              1013.0              1018.0            1013.0
# 4              1013.0              1018.0            1013.0
# 5              1013.0              1018.0            1013.0
# 6              1013.0              1018.0            1013.0
# 7              1013.0              1018.0            1013.0
# 8              1013.0              1018.0            1013.0
# 9              1013.0              1018.0            1013.0
#
#    Albuquerque_pressure  ...  Philadelphia  New York  Montreal  Boston  \
# 0                1024.0  ...          71.0      58.0      93.0    68.0
# 1                1024.0  ...          70.0      57.0      91.0    68.0
# 2                1024.0  ...          70.0      57.0      87.0    68.0
# 3                1024.0  ...          69.0      57.0      84.0    68.0
# 4                1024.0  ...          69.0      57.0      80.0    68.0
# 5                1024.0  ...          68.0      56.0      76.0    68.0
# 6                1024.0  ...          68.0      56.0      72.0    68.0
# 7                1024.0  ...          67.0      56.0      68.0    68.0
# 8                1024.0  ...          67.0      55.0      64.0    68.0
# 9                1024.0  ...          66.0      55.0      61.0    68.0
#
#    Beersheba  Tel Aviv District  Eilat  Haifa  Nahariyya  Jerusalem
# 0       50.0               63.0   22.0   51.0       51.0       50.0
# 1       51.0               62.0   22.0   51.0       51.0       50.0
# 2       51.0               62.0   22.0   51.0       51.0       50.0
# 3       52.0               62.0   22.0   51.0       51.0       50.0
# 4       54.0               62.0   23.0   51.0       51.0       50.0
# 5       55.0               63.0   23.0   51.0       51.0       50.0
# 6       56.0               63.0   23.0   51.0       51.0       50.0
# 7       57.0               63.0   24.0   51.0       51.0       50.0
# 8       58.0               64.0   24.0   51.0       51.0       50.0
# 9       59.0               64.0   24.0   51.0       51.0       50.0
#
# [10 rows x 109 columns]

# %%
all_col= ['Vancouver', 'Portland', 'San Francisco','Seattle', 'Los Angeles', 'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Philadelphia', 'New York', 'Montreal', 'Boston', 'Beersheba',	'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya',	'Jerusalem']
all_col_hum= []
for col in all_col: 
    all_col_hum.append(col+ "_humidity")


for i in all_col:
    t2.rename(columns={i: all_col_hum[all_col.index(i)]}, inplace=True)


t2.head(5)
# Out:
#               datetime  Vancouver_pressure  Portland_pressure  \
# 0  2012-10-01 13:00:00                 NaN             1024.0
# 1  2012-10-01 14:00:00                 NaN             1024.0
# 2  2012-10-01 15:00:00                 NaN             1024.0
# 3  2012-10-01 16:00:00                 NaN             1024.0
# 4  2012-10-01 17:00:00                 NaN             1024.0
#
#    San Francisco_pressure  Seattle_pressure  Los Angeles_pressure  \
# 0                  1009.0            1027.0                1013.0
# 1                  1009.0            1027.0                1013.0
# 2                  1009.0            1028.0                1013.0
# 3                  1009.0            1028.0                1013.0
# 4                  1009.0            1029.0                1013.0
#
#    San Diego_pressure  Las Vegas_pressure  Phoenix_pressure  \
# 0              1013.0              1018.0            1013.0
# 1              1013.0              1018.0            1013.0
# 2              1013.0              1018.0            1013.0
# 3              1013.0              1018.0            1013.0
# 4              1013.0              1018.0            1013.0
#
#    Albuquerque_pressure  ...  Philadelphia_humidity  New York_humidity  \
# 0                1024.0  ...                   71.0               58.0
# 1                1024.0  ...                   70.0               57.0
# 2                1024.0  ...                   70.0               57.0
# 3                1024.0  ...                   69.0               57.0
# 4                1024.0  ...                   69.0               57.0
#
#    Montreal_humidity  Boston_humidity  Beersheba_humidity  \
# 0               93.0             68.0                50.0
# 1               91.0             68.0                51.0
# 2               87.0             68.0                51.0
# 3               84.0             68.0                52.0
# 4               80.0             68.0                54.0
#
#    Tel Aviv District_humidity  Eilat_humidity  Haifa_humidity  \
# 0                        63.0            22.0            51.0
# 1                        62.0            22.0            51.0
# 2                        62.0            22.0            51.0
# 3                        62.0            22.0            51.0
# 4                        62.0            23.0            51.0
#
#    Nahariyya_humidity  Jerusalem_humidity
# 0                51.0                50.0
# 1                51.0                50.0
# 2                51.0                50.0
# 3                51.0                50.0
# 4                51.0                50.0
#
# [5 rows x 109 columns]

# %%
t2= pd.merge(left= t2, right=label, on= 'datetime')
t2.head(5)
# Out:
#               datetime  Vancouver_pressure  Portland_pressure  \
# 0  2012-10-01 13:00:00                 NaN             1024.0
# 1  2012-10-01 14:00:00                 NaN             1024.0
# 2  2012-10-01 15:00:00                 NaN             1024.0
# 3  2012-10-01 16:00:00                 NaN             1024.0
# 4  2012-10-01 17:00:00                 NaN             1024.0
#
#    San Francisco_pressure  Seattle_pressure  Los Angeles_pressure  \
# 0                  1009.0            1027.0                1013.0
# 1                  1009.0            1027.0                1013.0
# 2                  1009.0            1028.0                1013.0
# 3                  1009.0            1028.0                1013.0
# 4                  1009.0            1029.0                1013.0
#
#    San Diego_pressure  Las Vegas_pressure  Phoenix_pressure  \
# 0              1013.0              1018.0            1013.0
# 1              1013.0              1018.0            1013.0
# 2              1013.0              1018.0            1013.0
# 3              1013.0              1018.0            1013.0
# 4              1013.0              1018.0            1013.0
#
#    Albuquerque_pressure  ...   Philadelphia    New York         Montreal  \
# 0                1024.0  ...  broken clouds  few clouds  overcast clouds
# 1                1024.0  ...  broken clouds  few clouds     sky is clear
# 2                1024.0  ...  broken clouds  few clouds     sky is clear
# 3                1024.0  ...  broken clouds  few clouds     sky is clear
# 4                1024.0  ...  broken clouds  few clouds     sky is clear
#
#          Boston        Beersheba  Tel Aviv District          Eilat  \
# 0  sky is clear     sky is clear       sky is clear           haze
# 1    few clouds     sky is clear       sky is clear  broken clouds
# 2    few clouds  overcast clouds       sky is clear  broken clouds
# 3    few clouds  overcast clouds       sky is clear  broken clouds
# 4    few clouds  overcast clouds       sky is clear  broken clouds
#
#              Haifa        Nahariyya        Jerusalem
# 0     sky is clear     sky is clear     sky is clear
# 1  overcast clouds     sky is clear  overcast clouds
# 2  overcast clouds  overcast clouds  overcast clouds
# 3  overcast clouds  overcast clouds  overcast clouds
# 4  overcast clouds  overcast clouds  overcast clouds
#
# [5 rows x 145 columns]

# %%
seattle= t2[["Seattle_pressure", "Seattle_humidity", "Seattle_tempreture", "Seattle"]]
seattle = seattle.rename(columns={'Seattle_pressure': 'pressure', 'Seattle_tempreture':'tempreture', 'Seattle_humidity':'humidity','Seattle':'label'},)
seattle.head(5)
# Out:
#    pressure  humidity  tempreture         label
# 0    1027.0      81.0    8.650000  sky is clear
# 1    1027.0      80.0    8.647217  sky is clear
# 2    1028.0      80.0    8.639833  sky is clear
# 3    1028.0      79.0    8.632449  sky is clear
# 4    1029.0      79.0    8.625065  sky is clear

# %%
portland= t2[["Portland_pressure", "Portland_humidity", "Portland_tempreture", "Portland"]]
portland = portland.rename(columns={'Portland_pressure': 'pressure', 'Portland_tempreture':'tempreture', 'Portland_humidity':'humidity','Portland':'label'},)
portland.head(5)
# Out:
#    pressure  humidity  tempreture             label
# 0    1024.0      81.0    8.930000  scattered clouds
# 1    1024.0      80.0    8.933252  scattered clouds
# 2    1024.0      80.0    8.941866  scattered clouds
# 3    1024.0      80.0    8.950481  scattered clouds
# 4    1024.0      79.0    8.959095  scattered clouds

# %%
San_Diego= t2[["San Diego_pressure", "San Diego_humidity", "San Diego_tempreture", "San Diego"]]
San_Diego = San_Diego.rename(columns={'San Diego_pressure': 'pressure', 'San Diego_tempreture':'tempreture', 'San Diego_humidity':'humidity','San Diego':'label'},)
San_Diego.head(5)
# Out:
#    pressure  humidity  tempreture         label
# 0    1013.0      82.0   18.380000  sky is clear
# 1    1013.0      81.0   18.383501  sky is clear
# 2    1013.0      81.0   18.393355  sky is clear
# 3    1013.0      81.0   18.403209  sky is clear
# 4    1013.0      80.0   18.413063  sky is clear

# %%
seattle = seattle.append(portland, ignore_index= True )
# Out:
# <ipython-input-100-17ff6c3fdc16>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   seattle = seattle.append(portland, ignore_index= True )

# %%
seattle = seattle.append(San_Diego, ignore_index= True )
# Out:
# <ipython-input-135-69718b6c0240>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   seattle = seattle.append(San_Diego, ignore_index= True )

# %%
seattle.head()
# Out:
#    pressure  humidity  tempreture         label
# 0    1027.0      81.0    8.650000  sky is clear
# 1    1027.0      80.0    8.647217  sky is clear
# 2    1028.0      80.0    8.639833  sky is clear
# 3    1028.0      79.0    8.632449  sky is clear
# 4    1029.0      79.0    8.625065  sky is clear

# %%
seattle["label"][0]
# Out:
# 'sky is clear'

# %%
seattle["label"].value_counts()
# Out:
# sky is clear                    39355
# light rain                      17126
# broken clouds                   17022
# overcast clouds                 14328
# mist                            12019
# scattered clouds                10159
# few clouds                       9799
# moderate rain                    4947
# haze                             4225
# fog                              2461
# light intensity drizzle          1810
# heavy intensity rain             1448
# smoke                             532
# light snow                        130
# drizzle                            71
# light intensity shower rain        66
# proximity thunderstorm             53
# very heavy rain                    48
# snow                               43
# thunderstorm                       29
# dust                               16
# heavy snow                         13
# thunderstorm with light rain       13
# squalls                            11
# freezing rain                      11
# thunderstorm with rain              7
# heavy intensity drizzle             6
# shower rain                         3
# thunderstorm with heavy rain        2
# heavy intensity shower rain         1
# light shower snow                   1
# sleet                               1
# Name: label, dtype: int64

# %%
# test 
new_df = seattle

# %%
new_df = new_df.dropna() #remove empty rows

#Convert each category into an interger
for ind in new_df.index:
  if new_df["label"][ind]=='overcast clouds':
    new_df["label"][ind] = 0
  elif new_df["label"][ind]=='sky is clear':
    new_df["label"][ind] = 1
  elif new_df["label"][ind]=='light rain':
    new_df["label"][ind] = 2
  #elif new_df["Seattle"][ind]=='Drizzle':
  #  new_df["Seattle"][ind] = 2
  else:
    new_df = new_df.drop([ind]) #we don't consider other classes so we drop it

#Cast this column to int
new_df["label"] = new_df["label"].astype(int)

new_df.head() #show the 5 first rows of the dataframe
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# ...
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 2
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 1
# <ipython-input-140-d0c1eb942233>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["label"][ind] = 0
#    pressure  humidity  tempreture  label
# 0    1027.0      81.0    8.650000      1
# 1    1027.0      80.0    8.647217      1
# 2    1028.0      80.0    8.639833      1
# 3    1028.0      79.0    8.632449      1
# 4    1029.0      79.0    8.625065      1

# %%
# build the model

import tensorflow as tf

# %%
#Parameters :
NB_classes = 3 #number of outputs
NB_neurones = 30 #main number of neurones
NB_features = 3 #number of inputs
activation_func = tf.keras.activations.relu #activation function used

#Densly connected neural network
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(9,activation=activation_func,input_shape=(NB_features,)),
                             tf.keras.layers.Dense(27,activation=activation_func),
                            # tf.keras.layers.Dense(18,activation=activation_func),
                            # tf.keras.layers.Dense(9,activation=activation_func),
                            # tf.keras.layers.Dense(3,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                            #  tf.keras.layers.Dense(3,activation=activation_func),
                            #  tf.keras.layers.Dropout(0.4), #drop randomly some connection to avoid overfiting
                             #softmax will output an array containing probabilities of each classes
                             #the highest one is the predicted class
                             tf.keras.layers.Dense(NB_classes,activation=tf.keras.activations.softmax)
])

model.compile(optimizer="adam",loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy']) #compile the model
# model.build()
model.summary() #to see the paramter of our model
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 9)                 36
#
#  dense_41 (Dense)            (None, 27)                270
#
#  dense_42 (Dense)            (None, 3)                 84
#
# =================================================================
# Total params: 390
# Trainable params: 390
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_df["label"].value_counts()
# Out:
# 1    38898
# 2    17022
# 0    14222
# Name: label, dtype: int64

# %%
label_to_drop = new_df[new_df['label'] == 1].index


drop_samples = np.random.choice(label_to_drop, 20000, replace=False)
 

df_dropped = new_df.drop(drop_samples)

# %%
df_dropped["label"].value_counts()
# Out:
# 1    18898
# 2    17022
# 0    14222
# Name: label, dtype: int64

# %%
from keras.utils import to_categorical

labels = to_categorical(df_dropped.pop('label')) #Create classes from the labels

import numpy as np #import numpy library, used for arithmetic

features = np.array(df_dropped) #convert our dataframe into ndarray, only array type that neural network takes as input

# %%
df_dropped.head()
# Out:
#     pressure  humidity  tempreture
# 0     1027.0      81.0    8.650000
# 1     1027.0      80.0    8.647217
# 2     1028.0      80.0    8.639833
# 3     1028.0      79.0    8.632449
# 25    1046.0      67.0    8.470000

# %%
from sklearn.model_selection import train_test_split


#Split the dataset into training set 85% and test set 15%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.20,shuffle=True)

# %%
model.fit(x=train_features,
          y=train_labels,
          epochs=30,
          validation_data=(test_features,test_labels),
          verbose=1,
          shuffle=True) #Train our model
# Out:
# Epoch 1/30
# 1254/1254 [==============================] - 5s 3ms/step - loss: 2.9451 - accuracy: 0.4205 - val_loss: 1.0432 - val_accuracy: 0.4930
# Epoch 2/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1827 - accuracy: 0.4602 - val_loss: 1.2683 - val_accuracy: 0.4792
# Epoch 3/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1412 - accuracy: 0.4640 - val_loss: 1.7490 - val_accuracy: 0.5102
# Epoch 4/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1543 - accuracy: 0.4642 - val_loss: 1.0653 - val_accuracy: 0.4378
# Epoch 5/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1499 - accuracy: 0.4634 - val_loss: 1.0735 - val_accuracy: 0.4848
# Epoch 6/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1265 - accuracy: 0.4644 - val_loss: 1.2869 - val_accuracy: 0.4972
# Epoch 7/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1384 - accuracy: 0.4628 - val_loss: 1.2624 - val_accuracy: 0.4982
# Epoch 8/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1207 - accuracy: 0.4694 - val_loss: 1.0305 - val_accuracy: 0.5038
# Epoch 9/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1371 - accuracy: 0.4616 - val_loss: 0.9977 - val_accuracy: 0.4943
# Epoch 10/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1087 - accuracy: 0.4659 - val_loss: 0.9957 - val_accuracy: 0.5230
# Epoch 11/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1016 - accuracy: 0.4711 - val_loss: 1.0524 - val_accuracy: 0.5001
# Epoch 12/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1061 - accuracy: 0.4711 - val_loss: 1.3536 - val_accuracy: 0.3882
# Epoch 13/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0911 - accuracy: 0.4690 - val_loss: 0.9901 - val_accuracy: 0.5056
# Epoch 14/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.1022 - accuracy: 0.4709 - val_loss: 1.0466 - val_accuracy: 0.5144
# Epoch 15/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0881 - accuracy: 0.4706 - val_loss: 1.0191 - val_accuracy: 0.4980
# Epoch 16/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0846 - accuracy: 0.4771 - val_loss: 1.0023 - val_accuracy: 0.4843
# Epoch 17/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0706 - accuracy: 0.4788 - val_loss: 1.0275 - val_accuracy: 0.4765
# Epoch 18/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0660 - accuracy: 0.4819 - val_loss: 1.0055 - val_accuracy: 0.5035
# Epoch 19/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0535 - accuracy: 0.4826 - val_loss: 1.0044 - val_accuracy: 0.4959
# Epoch 20/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0480 - accuracy: 0.4831 - val_loss: 0.9746 - val_accuracy: 0.5085
# Epoch 21/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0422 - accuracy: 0.4873 - val_loss: 0.9803 - val_accuracy: 0.5019
# Epoch 22/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0533 - accuracy: 0.4834 - val_loss: 1.0052 - val_accuracy: 0.5085
# Epoch 23/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0338 - accuracy: 0.4882 - val_loss: 1.0592 - val_accuracy: 0.4674
# Epoch 24/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0280 - accuracy: 0.4891 - val_loss: 1.0764 - val_accuracy: 0.4712
# Epoch 25/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0316 - accuracy: 0.4859 - val_loss: 1.1169 - val_accuracy: 0.4683
# Epoch 26/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0203 - accuracy: 0.4944 - val_loss: 0.9515 - val_accuracy: 0.5306
# Epoch 27/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0113 - accuracy: 0.4991 - val_loss: 1.0458 - val_accuracy: 0.4374
# Epoch 28/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 1.0013 - accuracy: 0.5086 - val_loss: 0.9488 - val_accuracy: 0.5297
# Epoch 29/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 0.9966 - accuracy: 0.5081 - val_loss: 0.9619 - val_accuracy: 0.5244
# Epoch 30/30
# 1254/1254 [==============================] - 4s 3ms/step - loss: 0.9910 - accuracy: 0.5090 - val_loss: 0.9973 - val_accuracy: 0.5166

# %%
performance=model.evaluate(test_features,test_labels, batch_size=32, verbose=1, steps=None, )[1] * 100
print('Final accuracy : ', round(performance), '%')
# Out:
# 314/314 [==============================] - 1s 2ms/step - loss: 0.9973 - accuracy: 0.5166
# Final accuracy :  52 %

# %%
test_labels = np.argmax(test_labels,axis=1)
print(test_labels)
# Out:
# [0 0 0 ... 1 2 1]

# %%
# Passing the baseline Keras model to the TF Lite Converter.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Using  the Dynamic Range Quantization.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Converting the model
tflite_quant_model = converter.convert()
# Saving the model.
with open('dynamic_quant_model.tflite', 'wb') as f:
    f.write(tflite_quant_model)

# %%
#Function for evaluating TF Lite Model over Test Images
def evaluate(interpreter):
    prediction= []
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    input_format = interpreter.get_output_details()[0]['dtype']
    
    for i, test_image in enumerate(test_features):
        if i % 100 == 0:
            print('Evaluated on {n} results so far.'.format(n=i))
        test_image = np.expand_dims(test_image, axis=0).astype(input_format)
        interpreter.set_tensor(input_index, test_image)

        # Run inference.
        interpreter.invoke()
        output = interpreter.tensor(output_index)
        predicted_label = np.argmax(output()[0])
        prediction.append(predicted_label)

    print('\n')
    # Comparing prediction results with ground truth labels to calculate accuracy.
    prediction = np.array(prediction)
    print(prediction)
    print(test_labels)
    #accuracy = (prediction == test_labels)
    accuracy = (prediction == test_labels).mean()
    return accuracy

# %%
# Passing the Dynamic Range Quantized TF Lite model to the Interpreter.
interpreter = tf.lite.Interpreter('dynamic_quant_model.tflite') 
# Allocating tensors.
interpreter.allocate_tensors()
# Evaluating the model on the test images.
test_accuracy = evaluate(interpreter)
print('Dynamically Quantized TFLite Model Test Accuracy:', test_accuracy*100)
#print('Baseline Keras Model Test Accuracy:', baseline_model_accuracy*100)
# Out:
# Evaluated on 0 results so far.
# Evaluated on 100 results so far.
# Evaluated on 200 results so far.
# Evaluated on 300 results so far.
# Evaluated on 400 results so far.
# Evaluated on 500 results so far.
# Evaluated on 600 results so far.
# Evaluated on 700 results so far.
# Evaluated on 800 results so far.
# Evaluated on 900 results so far.
# Evaluated on 1000 results so far.
# Evaluated on 1100 results so far.
# Evaluated on 1200 results so far.
# Evaluated on 1300 results so far.
# Evaluated on 1400 results so far.
# Evaluated on 1500 results so far.
# Evaluated on 1600 results so far.
# Evaluated on 1700 results so far.
# Evaluated on 1800 results so far.
# Evaluated on 1900 results so far.
# Evaluated on 2000 results so far.
# Evaluated on 2100 results so far.
# Evaluated on 2200 results so far.
# Evaluated on 2300 results so far.
# Evaluated on 2400 results so far.
# Evaluated on 2500 results so far.
# Evaluated on 2600 results so far.
# Evaluated on 2700 results so far.
# Evaluated on 2800 results so far.
# Evaluated on 2900 results so far.
# Evaluated on 3000 results so far.
# Evaluated on 3100 results so far.
# Evaluated on 3200 results so far.
# Evaluated on 3300 results so far.
# Evaluated on 3400 results so far.
# Evaluated on 3500 results so far.
# Evaluated on 3600 results so far.
# Evaluated on 3700 results so far.
# Evaluated on 3800 results so far.
# Evaluated on 3900 results so far.
# Evaluated on 4000 results so far.
# Evaluated on 4100 results so far.
# Evaluated on 4200 results so far.
# Evaluated on 4300 results so far.
# Evaluated on 4400 results so far.
# Evaluated on 4500 results so far.
# Evaluated on 4600 results so far.
# Evaluated on 4700 results so far.
# Evaluated on 4800 results so far.
# Evaluated on 4900 results so far.
# Evaluated on 5000 results so far.
# Evaluated on 5100 results so far.
# Evaluated on 5200 results so far.
# Evaluated on 5300 results so far.
# Evaluated on 5400 results so far.
# Evaluated on 5500 results so far.
# Evaluated on 5600 results so far.
# Evaluated on 5700 results so far.
# Evaluated on 5800 results so far.
# Evaluated on 5900 results so far.
# Evaluated on 6000 results so far.
# Evaluated on 6100 results so far.
# Evaluated on 6200 results so far.
# Evaluated on 6300 results so far.
# Evaluated on 6400 results so far.
# Evaluated on 6500 results so far.
# Evaluated on 6600 results so far.
# Evaluated on 6700 results so far.
# Evaluated on 6800 results so far.
# Evaluated on 6900 results so far.
# Evaluated on 7000 results so far.
# Evaluated on 7100 results so far.
# Evaluated on 7200 results so far.
# Evaluated on 7300 results so far.
# Evaluated on 7400 results so far.
# Evaluated on 7500 results so far.
# Evaluated on 7600 results so far.
# Evaluated on 7700 results so far.
# Evaluated on 7800 results so far.
# Evaluated on 7900 results so far.
# Evaluated on 8000 results so far.
# Evaluated on 8100 results so far.
# Evaluated on 8200 results so far.
# Evaluated on 8300 results so far.
# Evaluated on 8400 results so far.
# Evaluated on 8500 results so far.
# Evaluated on 8600 results so far.
# Evaluated on 8700 results so far.
# Evaluated on 8800 results so far.
# Evaluated on 8900 results so far.
# Evaluated on 9000 results so far.
# Evaluated on 9100 results so far.
# Evaluated on 9200 results so far.
# Evaluated on 9300 results so far.
# Evaluated on 9400 results so far.
# Evaluated on 9500 results so far.
# Evaluated on 9600 results so far.
# Evaluated on 9700 results so far.
# Evaluated on 9800 results so far.
# Evaluated on 9900 results so far.
# Evaluated on 10000 results so far.
#
#
# [0 2 2 ... 0 2 2]
# [0 0 0 ... 1 2 1]
# Dynamically Quantized TFLite Model Test Accuracy: 51.58041679130522

# %%
# quantization
